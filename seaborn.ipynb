# %% [markdown]
# # SEABORN

# %%
import seaborn as sns

# %%
#to check the datasets
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data=sns.load_dataset("fmri")

# %%
data.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %% [markdown]
# # lineplot

# %%
sns.lineplot(x=data['timepoint'],y=data['signal'])
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x=data['timepoint'],y=data['signal'],hue=data['event'])
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x=data['timepoint'],y=data['signal'],hue=data['event'],style=data['region'])
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
x=[1,2,3,4,5,6,7]
y=[10,11,23,44,55,66,77]

# %%
sns.lineplot(x=x,y=y)
# Out:
# <AxesSubplot:>

# %%
data1=sns.load_dataset("tips")

# %%
data1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=data1,x='total_bill',y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.displot(x)

# %%
sns.catplot(data=data1,x='sex',y='total_bill',kind='bar')

# %%
sns.catplot(data=data1,x='sex',y='total_bill',kind='strip')

# %%
sns.catplot(data=data1,x='sex',y='total_bill',kind='violin')

# %%
sns.boxplot(data=data1,x='total_bill')
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.jointplot(data=data1,x='total_bill',y='tip')

# %%
cor=data.corr()

# %%
cor
# Out:
#            timepoint    signal
# timepoint   1.000000 -0.276935
# signal     -0.276935  1.000000

# %%
sns.heatmap(cor)
# Out:
# <AxesSubplot:>
